# %% [markdown]
# # ODE Exercises

# %%
# %pylab inline
import numpy as np
import matplotlib.pyplot as plt
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %% [raw]
# Question 1
# For this question refer to the solutions for the simple pendulum we got using scipy's odeint from the beginning of the ODE Tour.
# (a) Use the numerical solution to see what happens to the period of the pendulum as you change the initial angle of release. Plot θ vs. t for 5 different initial angles, θ0 , spanning 0 to π. (i.e. 0, π/4 , π/2 , 3π/4 , and π ). Put them all on the same plot. What happens to the period of the pendulum as the initial angle increases from π/4 to 3π/4? What happens to the trajectory when the initial angle is 0 or π ?

# %%
from scipy.integrate import odeint
def deriv(theta_current,t):
    g = 9.8
    ell = 0.5
    theta = theta_current[0]
    omega = theta_current[1]
    dtheta = omega
    domega = -(g/ell)*np.sin(theta)
    return np.array([dtheta,domega])

# %%
thetas = [0,np.pi/4.,np.pi/2.,3*np.pi/4,np.pi]
for a in thetas:
    t = np.arange(0.,50.+0.01,0.01)
    omega0 = 0
    th0 = a
    theta_init = np.array([th0,omega0])
    theta = odeint(deriv,theta_init,t)
    plt.plot(t,theta[:,0], label = ("Theta 0 = " + str(a)))
plt.grid()
plt.ylim(-20,5)
plt.xlim(0,25)
plt.xlabel("Time(seconds)",fontsize = 15)
plt.ylabel("Theta(Radians)",fontsize = 15)
plt.title("Theta vs Time",fontsize = 20)
plt.legend(loc = "lower left",fontsize = 10)

# %% [raw]
# (b) Make plots of θ vs. t, ω vs. t, and ω vs. θ (the so-called "phase plot") for θ0 = 0.95π. Look carefully at their behavior. What is going on in these figures?

# %%
t = np.arange(0.,50.+0.01,0.01)
omega0 = 0
th0 = 0.95*np.pi
theta_init = np.array([th0,omega0])
theta = odeint(deriv,theta_init,t)
plt.plot(t,theta[:,0],label = "Theta 0 = 0.95 pi")
plt.title("Theta(Radians) vs T(Seconds)")
plt.xlabel("Time(Seconds)")
plt.ylabel("Theta(Radians)")
plt.xlim(0,25)
# Out:
# (0, 25)

# %%
t = np.arange(0.,50.+0.01,0.01)
omega0 = 0
th0 = 0.95*np.pi
theta_init = np.array([th0,omega0])
theta = odeint(deriv,theta_init,t)
plt.plot(t,theta[:,1])
plt.title("Omega(Radians/second) vs T(Seconds)")
plt.xlabel("Time(Seconds)")
plt.ylabel("Omega(Radians/second)")
plt.xlim(0,25)
# Out:
# (0, 25)

# %%
t = np.arange(0.,50.+0.01,0.01)
omega0 = 0
th0 = 0.95*np.pi
theta_init = np.array([th0,omega0])
theta = odeint(deriv,theta_init,t)
plt.plot(theta[:,0],theta[:,1])
plt.title("Omega(Radians/second) vs Theta (Radians)")
plt.xlabel("Theta(Radians)")
plt.ylabel("Omega(Radians/second)")
plt.xlim(-10,10)
# Out:
# (-10, 10)

# %% [raw]
# (c) For the θ0 = 0.95π case, check that energy is conserved by plotting E/m vs. t (where E/m=gℓ(1−cos(θ))+12ℓ2ω2 ).
# Is the energy a constant? If not, then the computational errors are producing a non-physical loss (or gain) of energy. Review the documentation for odeint and change the error tolerance value to a tighter number.

# %%
g = 9.8
ell = 0.5
Em = g*ell*(1-cos(theta[:,0]))+(1/2.)*ell**2*(theta[:,1]**2)
plt.ylim(0,12)
plt.plot(t,Em)

# %% [raw]
# (d) Now look at what happens if we start the pendulum straight up, θ=π. Go for at least 50 s. Be sure to describe what happens numerically according to the θ vs. t, ω vs. t and E/m vs. t plots. What do you think should happen? What happens if you change the error tolerance on odeint? How does this compare to a nearly vertical pendulum: θ0=π−0.000001 ?

# %%
t = np.arange(0.,50.+0.01,0.01)
omega0 = 0
th0 = np.pi
theta_init = np.array([th0,omega0])
theta = odeint(deriv,theta_init,t)
plt.plot(t,theta[:,0],label = "Theta 0 = 0.95 pi")
plt.title("Theta(Radians) vs T(Seconds)")
plt.xlabel("Time(Seconds)")
plt.ylabel("Theta(Radians)")
plt.xlim(0,25)
# Out:
# (0, 25)

# %%
t = np.arange(0.,50.+0.01,0.01)
omega0 = 0
th0 = np.pi
theta_init = np.array([th0,omega0])
theta = odeint(deriv,theta_init,t)
plt.plot(t,theta[:,1])
plt.title("Omega(Radians/second) vs T(Seconds)")
plt.xlabel("Time(Seconds)")
plt.ylabel("Omega(Radians/second)")
plt.xlim(0,25)
plt.ylim(-10,5)
# Out:
# (-10, 5)

# %%
t = np.arange(0.,55.+0.01,0.01)
omega0 = 0
theta_init = np.array([th0,omega0])
theta = odeint(deriv,theta_init,t)
plt.plot(theta[:,0],theta[:,1])
plt.title("Omega(Radians/second) vs Theta (Radians)")
plt.xlabel("Theta(Radians)")
plt.ylabel("Omega(Radians/second)")
plt.xlim(-10,10)
plt.ylim(-10,10)
# Out:
# (-10, 10)

# %%
g = 9.8
ell = 0.5
Em = g*ell*(1-cos(theta[:,0]))+(1/2.)*ell**2*(theta[:,1]**2)
plt.ylim(0,12)
plt.plot(t,Em)

# %%
#th0 = pi - 0.000001
t = np.arange(0.,50.+0.01,0.01)
omega0 = 0
th0 = np.pi-0.000001
theta_init = np.array([th0,omega0])
theta = odeint(deriv,theta_init,t)
plt.plot(t,theta[:,0],label = "Theta 0 = 0.95 pi")
plt.title("Theta(Radians) vs T(Seconds)")
plt.xlabel("Time(Seconds)")
plt.ylabel("Theta(Radians)")
plt.xlim(0,25)
# Out:
# (0, 25)

# %%
t = np.arange(0.,50.+0.01,0.01)
omega0 = 0
theta_init = np.array([th0,omega0])
theta = odeint(deriv,theta_init,t)
plt.plot(t,theta[:,1])
plt.title("Omega(Radians/second) vs T(Seconds)")
plt.xlabel("Time(Seconds)")
plt.ylabel("Omega(Radians/second)")
plt.xlim(0,25)
plt.ylim(-10,10)
# Out:
# (-10, 10)

# %%
t = np.arange(0.,55.+0.01,0.01)
omega0 = 0
theta_init = np.array([th0,omega0])
theta = odeint(deriv,theta_init,t)
plt.plot(theta[:,0],theta[:,1])
plt.title("Omega(Radians/second) vs Theta (Radians)")
plt.xlabel("Theta(Radians)")
plt.ylabel("Omega(Radians/second)")
plt.xlim(-10,10)
plt.ylim(-10,10)
# Out:
# (-10, 10)

# %%
g = 9.8
ell = 0.5
Em = g*ell*(1-cos(theta[:,0]))+(1/2.)*ell**2*(theta[:,1]**2)
plt.ylim(0,12)
plt.plot(t,Em)

# %% [raw]
# Question 2
# (a) Use Euler's method (not odeint) to solve the following first-order differential equation with given initial condition y(0) = 0.
# dydx=x+2y
# Find the value of y when x = 1, y(1), using two different step sizes: 0.25 then 0.02.

# %%
x = 0
y0 = 0
stepSize = .25
yx = []
yx.append(0)
dydx = lambda x,y: x + 2*y
while x < 10:
    yx.append(yx[int(x/.25)] + dydx(x,yx[int(x/.25)])*stepSize)
    x += stepSize
print yx
# Out:
# [0, 0.0, 0.0625, 0.21875, 0.515625, 1.0234375, 1.84765625, 3.146484375, 5.1572265625, 8.23583984375, 12.916259765625, 19.9993896484375, 30.68658447265625, 46.779876708984375, 70.98231506347656, 107.34847259521484, 161.96020889282227, 243.9403133392334, 366.9729700088501, 551.5844550132751, 828.5641825199127, 1244.096273779869, 1867.4569106698036, 2802.5603660047054, 4205.278049007058, 6309.417073510587, 9465.68811026588, 14200.157165398821, 21301.923248098232, 31954.634872147348, 47933.76480822102, 71902.52221233153, 107855.7208184973, 161785.58122774595, 242680.4343416189, 364022.77651242836, 546036.3522686425, 819056.7784029638, 1228587.4801044457, 1842883.5951566687, 2764327.830235003]
